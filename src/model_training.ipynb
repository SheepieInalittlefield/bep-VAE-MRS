# %%
import wandb
wandb.login()
# Out:
# True

# %%
# %load_ext autoreload
# %autoreload 2
from data import load_mrs
from config import custom_VAE_config, custom_beta_VAE_config, basic_VAE_config
from models import MRS_decoder, MRS_encoder
from training import get_model, get_callback, get_pipeline, train
from visualization import show_generated_data, sample_model
from random import randint
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
train_dataset, eval_dataset, ppm = load_mrs()

# %%
# %%capture
config, model_config = custom_VAE_config()

wandb_callback = get_callback(config, model_config)

encoder = MRS_encoder(model_config)
decoder = MRS_decoder(model_config)
model = get_model(model_config, encoder, decoder)

pipeline = get_pipeline(model, config)

trained_model = train('custom_VAE', pipeline, train_dataset, eval_dataset, wandb_callback)
# Out:
# Preprocessing train data...
# Checking train dataset...
# Preprocessing eval data...
#
# Checking eval dataset...
# Using Base Trainer
#
# Model passed sanity check !
# Ready for training.
#
# Created custom_VAE/VAE_training_2023-05-17_02-22-57.
# Training config, checkpoints and final model will be saved here.
#
# Training params:
#  - max_epochs: 250
#  - per_device_train_batch_size: 64
#  - per_device_eval_batch_size: 64
#  - checkpoint saving every: None
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.91, 0.99)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.0002
#     maximize: False
#     weight_decay: 0.05
# )
# Scheduler: None
#
# Successfully launched training !
#
# --------------------------------------------------------------------------
# Train loss: 307.5293
# Eval loss: 36.3665
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 196.196
# Eval loss: 27.7448
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 142.6786
# Eval loss: 24.8474
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 114.441
# Eval loss: 24.8179
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 74.8039
# Eval loss: 26.7289
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 61.1132
# Eval loss: 30.278
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 54.3212
# Eval loss: 30.9971
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 35.6115
# Eval loss: 34.2468
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 121.4983
# Eval loss: 39.294
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 43.4648
# Eval loss: 43.0373
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 40.4247
# Eval loss: 47.6746
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 36.7748
# Eval loss: 55.8867
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 62.6186
# Eval loss: 68.6117
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 30.0736
# Eval loss: 82.5753
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 56.0036
# Eval loss: 110.7235
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 31.3328
# Eval loss: 140.3638
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 44.0282
# Eval loss: 158.5855
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 29.5997
# Eval loss: 146.6058
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 28.1179
# Eval loss: 123.4155
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 28.5002
# Eval loss: 201.1614
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 26.5161
# Eval loss: 202.6572
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 27.6222
# Eval loss: 128.2528
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 26.2084
# Eval loss: 95.0772
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 26.3861
# Eval loss: 148.5644
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 24.5124
# Eval loss: 86.2472
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 24.9892
# Eval loss: 90.937
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 24.7292
# Eval loss: 108.3343
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 23.6296
# Eval loss: 46.134
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 35.0245
# Eval loss: 44.3677
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 27.2395
# Eval loss: 30.683
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 30.544
# Eval loss: 29.7918
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 23.9176
# Eval loss: 31.1209
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 31.0707
# Eval loss: 28.1952
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 24.1139
# Eval loss: 29.2459
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 24.8541
# Eval loss: 26.4001
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 23.7596
# Eval loss: 27.9364
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 24.429
# Eval loss: 24.2239
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 28.1837
# Eval loss: 24.5887
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 23.8023
# Eval loss: 27.3933
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 24.1303
# Eval loss: 26.0084
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 23.3842
# Eval loss: 24.4979
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 24.6981
# Eval loss: 24.4248
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 23.8234
# Eval loss: 25.0062
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 24.8597
# Eval loss: 23.8495
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 23.3355
# Eval loss: 24.3066
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 23.6419
# Eval loss: 25.0892
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 24.7609
# Eval loss: 23.6576
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 31.9744
# Eval loss: 22.6107
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 24.2251
# Eval loss: 26.3494
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 24.0651
# Eval loss: 23.2671
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 22.9092
# Eval loss: 23.0956
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 22.71
# Eval loss: 25.4235
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 23.0179
# Eval loss: 29.0503
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 24.8776
# Eval loss: 23.4272
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 26.481
# Eval loss: 34.4506
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 22.5723
# Eval loss: 22.6089
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 22.8743
# Eval loss: 22.347
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 22.3019
# Eval loss: 43.9333
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 22.4906
# Eval loss: 42.1152
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 22.3915
# Eval loss: 31.0772
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 22.9867
# Eval loss: 22.676
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 26.9246
# Eval loss: 21.5306
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 22.7898
# Eval loss: 26.7299
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 21.6539
# Eval loss: 26.7657
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 21.9484
# Eval loss: 23.407
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 26.7977
# Eval loss: 22.5399
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 22.0611
# Eval loss: 28.1064
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 22.5411
# Eval loss: 22.3654
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 23.0041
# Eval loss: 23.008
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 22.8372
# Eval loss: 27.8862
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 24.2712
# Eval loss: 23.7722
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 22.4008
# Eval loss: 21.682
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 22.1022
# Eval loss: 21.6504
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 22.0749
# Eval loss: 21.2788
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 25.7527
# Eval loss: 21.2462
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 24.2854
# Eval loss: 21.8584
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 22.3348
# Eval loss: 22.0276
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 23.2489
# Eval loss: 23.7685
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 23.0835
# Eval loss: 22.0189
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 22.2397
# Eval loss: 23.8202
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 21.7775
# Eval loss: 22.1611
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 22.6342
# Eval loss: 23.5557
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 24.8169
# Eval loss: 21.8418
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 22.2321
# Eval loss: 22.2943
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 22.3007
# Eval loss: 23.7953
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 21.8444
# Eval loss: 21.4768
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 22.324
# Eval loss: 22.6212
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 21.6435
# Eval loss: 22.4884
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 22.5744
# Eval loss: 20.4512
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 22.09
# Eval loss: 22.902
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 21.7846
# Eval loss: 21.4587
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 21.5047
# Eval loss: 21.2917
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 21.2099
# Eval loss: 21.2246
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 20.9013
# Eval loss: 22.8799
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 21.7173
# Eval loss: 22.4027
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 21.6476
# Eval loss: 20.3915
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 20.9445
# Eval loss: 21.1931
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 20.5114
# Eval loss: 20.7132
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 20.6041
# Eval loss: 21.3204
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 20.3017
# Eval loss: 20.343
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 21.4686
# Eval loss: 20.7422
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 20.5346
# Eval loss: 20.3916
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 20.963
# Eval loss: 20.7362
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 21.0701
# Eval loss: 20.5481
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 20.5198
# Eval loss: 21.4673
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 20.3768
# Eval loss: 21.125
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 21.1645
# Eval loss: 20.5795
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 19.8304
# Eval loss: 20.1108
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 20.4503
# Eval loss: 20.3291
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 19.8649
# Eval loss: 21.2037
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 20.0803
# Eval loss: 19.955
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 20.0453
# Eval loss: 20.7043
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 20.765
# Eval loss: 19.239
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 19.5169
# Eval loss: 19.3516
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 20.2238
# Eval loss: 19.7808
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 19.45
# Eval loss: 18.9943
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 19.5995
# Eval loss: 18.7329
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 19.3871
# Eval loss: 18.8688
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 19.1728
# Eval loss: 18.4367
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 20.2369
# Eval loss: 18.856
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 19.6476
# Eval loss: 18.691
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 19.9609
# Eval loss: 18.4146
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 18.8276
# Eval loss: 18.5617
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 19.4374
# Eval loss: 18.3731
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 19.8308
# Eval loss: 18.6749
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 18.5126
# Eval loss: 19.1126
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 18.2047
# Eval loss: 17.9666
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 18.6661
# Eval loss: 18.38
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 19.2873
# Eval loss: 17.9376
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 18.3668
# Eval loss: 17.5774
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 18.0918
# Eval loss: 16.7716
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 17.664
# Eval loss: 16.9885
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 18.2892
# Eval loss: 17.6513
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 17.5948
# Eval loss: 17.0306
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 17.0927
# Eval loss: 19.6994
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 16.6548
# Eval loss: 17.1583
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 17.1402
# Eval loss: 17.0973
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 16.5834
# Eval loss: 16.919
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 18.5898
# Eval loss: 16.8432
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 16.1755
# Eval loss: 15.6782
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 16.5171
# Eval loss: 16.8921
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 16.4906
# Eval loss: 16.0091
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 16.0718
# Eval loss: 15.0438
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 15.9733
# Eval loss: 15.9257
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 15.7118
# Eval loss: 20.403
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 15.2276
# Eval loss: 24.4825
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 17.0841
# Eval loss: 16.4254
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 15.8122
# Eval loss: 16.4167
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 14.9228
# Eval loss: 18.0236
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 15.4874
# Eval loss: 17.0066
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 15.2247
# Eval loss: 16.1796
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 14.7619
# Eval loss: 13.8522
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 14.5055
# Eval loss: 15.8361
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 14.2139
# Eval loss: 13.4375
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 13.6586
# Eval loss: 13.0487
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 15.101
# Eval loss: 13.324
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 13.2773
# Eval loss: 15.5746
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 13.1874
# Eval loss: 12.784
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 12.881
# Eval loss: 13.6391
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 15.3115
# Eval loss: 12.8689
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 13.6513
# Eval loss: 13.9322
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 12.8576
# Eval loss: 13.1573
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 12.3123
# Eval loss: 12.4252
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 12.3977
# Eval loss: 14.2619
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 14.0586
# Eval loss: 19.1462
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 11.4382
# Eval loss: 12.4901
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 11.4373
# Eval loss: 11.7418
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 11.8564
# Eval loss: 11.8912
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 11.1827
# Eval loss: 13.8263
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 11.1904
# Eval loss: 10.6973
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 11.3937
# Eval loss: 10.326
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 10.9279
# Eval loss: 10.6961
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 10.9379
# Eval loss: 12.344
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 12.0413
# Eval loss: 10.8281
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 10.2381
# Eval loss: 10.8071
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 11.5213
# Eval loss: 11.5146
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 11.0428
# Eval loss: 11.2141
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 10.3121
# Eval loss: 12.5856
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 10.0589
# Eval loss: 10.4447
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 9.4834
# Eval loss: 11.5186
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 13.5334
# Eval loss: 10.2299
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 9.874
# Eval loss: 10.0075
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 9.3698
# Eval loss: 10.3582
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 10.3214
# Eval loss: 10.7293
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 9.472
# Eval loss: 10.7305
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 11.9925
# Eval loss: 10.0164
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 9.0397
# Eval loss: 11.3972
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 8.8928
# Eval loss: 11.5545
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 12.9777
# Eval loss: 10.515
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 8.3206
# Eval loss: 11.4376
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 9.2749
# Eval loss: 9.6778
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 8.5271
# Eval loss: 8.9664
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 8.8439
# Eval loss: 9.6495
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 8.6173
# Eval loss: 12.4797
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 8.6126
# Eval loss: 12.7349
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 9.4222
# Eval loss: 9.3842
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 8.3973
# Eval loss: 10.0488
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 9.2979
# Eval loss: 13.4975
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 8.4978
# Eval loss: 9.3194
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 8.6141
# Eval loss: 14.9826
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 8.1379
# Eval loss: 8.4873
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 7.9878
# Eval loss: 8.1161
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 7.9242
# Eval loss: 8.9291
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 7.8746
# Eval loss: 7.4487
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 8.6573
# Eval loss: 7.4584
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 7.6611
# Eval loss: 8.7793
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 7.5752
# Eval loss: 7.9169
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 7.2881
# Eval loss: 7.9332
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 7.5567
# Eval loss: 7.3644
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 7.2902
# Eval loss: 7.8703
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 7.376
# Eval loss: 7.2128
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 7.2111
# Eval loss: 7.3882
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 8.9919
# Eval loss: 7.1534
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 7.3114
# Eval loss: 8.3915
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 7.0624
# Eval loss: 6.9082
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 7.2007
# Eval loss: 7.8103
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 6.8631
# Eval loss: 7.5018
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 6.889
# Eval loss: 6.8887
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 6.8951
# Eval loss: 12.4861
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 6.342
# Eval loss: 6.9011
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 6.3627
# Eval loss: 8.286
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 6.556
# Eval loss: 6.4995
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 6.4925
# Eval loss: 9.8466
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 6.5834
# Eval loss: 6.2674
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 6.0824
# Eval loss: 7.0576
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 5.889
# Eval loss: 7.7983
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 5.98
# Eval loss: 6.5953
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 5.8282
# Eval loss: 6.0471
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 5.4435
# Eval loss: 8.2629
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 5.7364
# Eval loss: 5.8113
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 6.0817
# Eval loss: 5.6849
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 5.6622
# Eval loss: 5.4873
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 6.3057
# Eval loss: 5.6946
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 6.4992
# Eval loss: 5.5494
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 5.4744
# Eval loss: 8.5181
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 5.3886
# Eval loss: 5.9208
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 5.76
# Eval loss: 5.0366
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 5.5737
# Eval loss: 8.6947
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 5.1935
# Eval loss: 5.2279
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 5.2157
# Eval loss: 6.3169
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 5.1142
# Eval loss: 4.8089
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 5.483
# Eval loss: 5.2326
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 5.1364
# Eval loss: 5.125
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 5.0052
# Eval loss: 4.89
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 4.8353
# Eval loss: 4.8819
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 4.754
# Eval loss: 4.8113
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 4.8594
# Eval loss: 4.6158
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 4.5261
# Eval loss: 4.6861
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 4.6575
# Eval loss: 4.7003
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 4.7173
# Eval loss: 4.7583
# --------------------------------------------------------------------------
# Training ended!
# Saved final model in custom_VAE/VAE_training_2023-05-17_02-22-57/final_model

# %%
gen_data = sample_model(trained_model)
gen_data = gen_data.cpu()
select = randint(0,39)
show_generated_data(gen_data, eval_dataset[select], ppm)
# Out:
# (2048,)
# (2048,)
# (2048,)
# MSE: 0.0027654723234473502

# %%
# %%capture
config, model_config = custom_beta_VAE_config()

wandb_callback = get_callback(config, model_config)
model = get_model(model_config)

pipeline = get_pipeline(model, config)

trained_model = train('custom_beta_VAE', pipeline, train_dataset, eval_dataset, wandb_callback)
# Out:
# Preprocessing train data...
# Checking train dataset...
# Preprocessing eval data...
#
# Checking eval dataset...
# Using Base Trainer
#
# Model passed sanity check !
# Ready for training.
#
# Created custom_beta_VAE/VAE_training_2023-05-17_02-23-43.
# Training config, checkpoints and final model will be saved here.
#
# Training params:
#  - max_epochs: 250
#  - per_device_train_batch_size: 64
#  - per_device_eval_batch_size: 64
#  - checkpoint saving every: None
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.91, 0.99)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.0002
#     maximize: False
#     weight_decay: 0.05
# )
# Scheduler: None
#
# Successfully launched training !
#
# --------------------------------------------------------------------------
# Train loss: 175.7823
# Eval loss: 38.367
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 89.7518
# Eval loss: 41.9308
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 58.5198
# Eval loss: 46.4517
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 46.6618
# Eval loss: 53.717
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 39.917
# Eval loss: 51.5738
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 54.8384
# Eval loss: 48.7896
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 32.6582
# Eval loss: 43.1353
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 31.9827
# Eval loss: 40.4275
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 32.4233
# Eval loss: 37.2483
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 36.3554
# Eval loss: 35.6094
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 31.4707
# Eval loss: 34.0562
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 27.8906
# Eval loss: 35.1934
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 30.7237
# Eval loss: 35.6575
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 26.1429
# Eval loss: 37.4521
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 29.1052
# Eval loss: 39.448
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 30.035
# Eval loss: 45.0249
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 26.7877
# Eval loss: 50.4618
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 27.3349
# Eval loss: 57.3654
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 23.9971
# Eval loss: 64.7608
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 30.6669
# Eval loss: 125.8493
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 24.7881
# Eval loss: 65.3506
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 26.6832
# Eval loss: 45.373
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 25.5385
# Eval loss: 76.7702
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 26.3039
# Eval loss: 32.2138
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 25.7213
# Eval loss: 29.3562
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 24.4594
# Eval loss: 36.2404
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 24.9104
# Eval loss: 32.4733
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 24.1322
# Eval loss: 26.2672
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 22.9533
# Eval loss: 24.5621
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 22.728
# Eval loss: 23.9731
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 22.4932
# Eval loss: 23.1732
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 22.2594
# Eval loss: 22.8973
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 23.8417
# Eval loss: 30.6175
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 26.7634
# Eval loss: 22.3512
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 22.4893
# Eval loss: 22.5233
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 21.9146
# Eval loss: 22.9044
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 22.9014
# Eval loss: 22.5633
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 22.2958
# Eval loss: 22.4307
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 22.0072
# Eval loss: 27.8948
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 21.7409
# Eval loss: 21.7083
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 21.9607
# Eval loss: 22.4397
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 21.6651
# Eval loss: 21.3581
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 23.186
# Eval loss: 21.6131
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 21.7481
# Eval loss: 21.9375
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 21.6715
# Eval loss: 22.1457
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 21.3395
# Eval loss: 21.7749
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 21.1232
# Eval loss: 22.5599
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 21.3837
# Eval loss: 21.3901
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 21.3971
# Eval loss: 21.269
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 23.037
# Eval loss: 21.5363
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 20.9999
# Eval loss: 20.7488
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 22.5768
# Eval loss: 21.5885
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 21.6115
# Eval loss: 20.9447
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 21.3206
# Eval loss: 21.0252
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 21.1084
# Eval loss: 21.3328
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 20.9888
# Eval loss: 20.7548
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 20.9123
# Eval loss: 22.0651
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 21.3435
# Eval loss: 21.0888
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 20.8972
# Eval loss: 20.5289
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 20.7027
# Eval loss: 21.5488
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 20.6229
# Eval loss: 20.2956
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 20.5319
# Eval loss: 20.1467
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 20.7343
# Eval loss: 20.8416
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 20.4665
# Eval loss: 20.2103
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 20.4755
# Eval loss: 21.0939
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 20.2285
# Eval loss: 20.1762
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 20.663
# Eval loss: 19.771
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 21.388
# Eval loss: 20.1031
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 20.3422
# Eval loss: 20.5768
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 20.1571
# Eval loss: 20.2477
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 21.5453
# Eval loss: 20.5677
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 20.5697
# Eval loss: 19.7786
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 20.5845
# Eval loss: 19.7233
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 20.5209
# Eval loss: 19.9714
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 20.2588
# Eval loss: 19.701
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 19.6289
# Eval loss: 21.3638
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 19.9026
# Eval loss: 21.0354
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 19.8276
# Eval loss: 19.4918
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 19.6128
# Eval loss: 19.4621
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 19.6843
# Eval loss: 19.2951
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 19.5552
# Eval loss: 19.2093
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 20.8102
# Eval loss: 18.7395
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 20.5687
# Eval loss: 18.9382
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 19.5602
# Eval loss: 18.6415
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 19.6498
# Eval loss: 20.6724
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 19.2631
# Eval loss: 19.3501
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 19.6364
# Eval loss: 18.8323
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 19.8035
# Eval loss: 19.2462
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 19.3322
# Eval loss: 18.9426
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 19.0077
# Eval loss: 18.9042
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 18.9178
# Eval loss: 22.0647
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 19.7791
# Eval loss: 18.9704
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 18.7187
# Eval loss: 18.4304
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 18.8872
# Eval loss: 18.0222
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 18.6669
# Eval loss: 18.8344
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 18.7352
# Eval loss: 17.6909
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 18.4883
# Eval loss: 17.8296
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 18.424
# Eval loss: 17.8101
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 18.6968
# Eval loss: 18.1189
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 18.687
# Eval loss: 18.1707
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 18.2571
# Eval loss: 18.3491
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 17.973
# Eval loss: 17.9904
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 18.2086
# Eval loss: 17.9324
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 17.763
# Eval loss: 17.2659
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 18.0921
# Eval loss: 16.8679
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 17.5732
# Eval loss: 17.6098
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 17.7259
# Eval loss: 17.4211
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 17.3496
# Eval loss: 16.7554
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 17.1563
# Eval loss: 17.8724
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 16.9044
# Eval loss: 18.7466
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 16.726
# Eval loss: 16.2706
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 17.7783
# Eval loss: 16.3148
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 16.7092
# Eval loss: 16.8858
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 16.765
# Eval loss: 16.9819
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 16.5763
# Eval loss: 17.1082
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 16.4231
# Eval loss: 16.5353
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 16.1105
# Eval loss: 16.298
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 16.0474
# Eval loss: 15.419
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 16.6222
# Eval loss: 17.173
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 15.4719
# Eval loss: 15.4087
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 15.3175
# Eval loss: 15.5339
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 15.097
# Eval loss: 15.2761
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 14.7673
# Eval loss: 20.5205
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 14.5563
# Eval loss: 14.6454
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 14.3688
# Eval loss: 14.8542
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 15.0675
# Eval loss: 14.0783
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 14.1545
# Eval loss: 14.9868
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 15.0055
# Eval loss: 14.8126
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 13.6198
# Eval loss: 14.3205
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 13.3882
# Eval loss: 13.911
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 13.1514
# Eval loss: 14.1085
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 12.7664
# Eval loss: 13.4234
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 12.4523
# Eval loss: 12.6255
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 12.782
# Eval loss: 14.487
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 11.9414
# Eval loss: 13.362
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 10.9855
# Eval loss: 13.0221
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 10.9324
# Eval loss: 11.8743
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 12.1186
# Eval loss: 11.6064
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 10.0613
# Eval loss: 15.6623
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 10.5541
# Eval loss: 11.0795
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 11.7438
# Eval loss: 10.3238
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 11.0104
# Eval loss: 10.3287
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 9.8665
# Eval loss: 11.5255
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 9.9633
# Eval loss: 10.6514
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 10.0985
# Eval loss: 12.0658
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 9.4399
# Eval loss: 9.1883
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 8.3188
# Eval loss: 9.6275
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 8.5713
# Eval loss: 9.6371
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 8.5638
# Eval loss: 8.3535
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 7.6381
# Eval loss: 7.995
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 8.3032
# Eval loss: 8.805
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 7.6813
# Eval loss: 8.6828
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 7.837
# Eval loss: 8.5621
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 7.8096
# Eval loss: 8.9407
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 7.2881
# Eval loss: 7.574
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 7.8242
# Eval loss: 8.259
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 7.1177
# Eval loss: 8.0552
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 6.8833
# Eval loss: 8.7673
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 6.8408
# Eval loss: 7.1173
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 6.9348
# Eval loss: 5.8637
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 6.3103
# Eval loss: 6.3887
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 6.2067
# Eval loss: 6.5457
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 5.7736
# Eval loss: 6.0687
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 6.0798
# Eval loss: 5.9731
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 5.8421
# Eval loss: 5.6373
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 5.5131
# Eval loss: 5.3162
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 5.9099
# Eval loss: 6.1391
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 5.8162
# Eval loss: 5.8979
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 5.2182
# Eval loss: 5.0924
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 5.5388
# Eval loss: 5.7706
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 4.9437
# Eval loss: 4.7703
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 5.0431
# Eval loss: 5.2597
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 5.1428
# Eval loss: 5.6476
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 4.7774
# Eval loss: 4.9083
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 4.6579
# Eval loss: 4.4196
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 4.6301
# Eval loss: 4.3908
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 4.479
# Eval loss: 4.283
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 4.4144
# Eval loss: 4.8038
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 4.1133
# Eval loss: 4.2633
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 4.3294
# Eval loss: 3.4355
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 3.7024
# Eval loss: 4.3546
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 3.9896
# Eval loss: 3.8376
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 3.7172
# Eval loss: 3.8691
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 3.8448
# Eval loss: 3.7114
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 3.5257
# Eval loss: 3.3012
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 3.4955
# Eval loss: 3.4039
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 3.3599
# Eval loss: 3.6081
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 3.9202
# Eval loss: 3.1362
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 3.2525
# Eval loss: 3.1861
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 3.3688
# Eval loss: 3.7844
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 3.3002
# Eval loss: 3.3903
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 3.4444
# Eval loss: 3.6828
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 3.2397
# Eval loss: 3.1386
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 3.0795
# Eval loss: 3.2493
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 3.0412
# Eval loss: 3.2367
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 3.1856
# Eval loss: 2.8225
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 3.0498
# Eval loss: 3.0464
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 3.0378
# Eval loss: 2.7484
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 3.0923
# Eval loss: 2.9039
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 2.9499
# Eval loss: 2.8883
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 2.8442
# Eval loss: 3.0516
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 3.009
# Eval loss: 2.7252
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 2.9188
# Eval loss: 2.6607
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 2.8326
# Eval loss: 3.185
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 2.9157
# Eval loss: 2.8817
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 2.8237
# Eval loss: 2.7319
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 2.7251
# Eval loss: 2.81
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 2.7172
# Eval loss: 2.8558
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 2.7473
# Eval loss: 2.7381
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 2.6879
# Eval loss: 2.5517
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 2.5644
# Eval loss: 2.6394
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 2.5561
# Eval loss: 2.6583
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 2.5906
# Eval loss: 2.5023
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 2.488
# Eval loss: 2.5819
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 2.5061
# Eval loss: 2.4612
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 2.4222
# Eval loss: 2.4099
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 2.4326
# Eval loss: 2.412
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 2.3272
# Eval loss: 2.348
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 2.4324
# Eval loss: 2.4486
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 2.3681
# Eval loss: 2.3263
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 2.3784
# Eval loss: 2.3491
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 2.3429
# Eval loss: 2.3481
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 2.3648
# Eval loss: 2.3694
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 2.3124
# Eval loss: 2.3195
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 2.3578
# Eval loss: 2.2149
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 2.2928
# Eval loss: 2.2685
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 2.2938
# Eval loss: 2.2613
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 2.2612
# Eval loss: 2.3577
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 2.5297
# Eval loss: 2.2487
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 2.2652
# Eval loss: 2.2675
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 2.3702
# Eval loss: 4.1926
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 2.3595
# Eval loss: 2.1913
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 2.4243
# Eval loss: 2.5731
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 2.2316
# Eval loss: 2.1766
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 2.2909
# Eval loss: 2.2581
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 2.2252
# Eval loss: 2.2611
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 2.3227
# Eval loss: 2.2172
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 2.2059
# Eval loss: 2.2405
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 2.3379
# Eval loss: 2.2275
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 2.2209
# Eval loss: 2.2946
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 2.3824
# Eval loss: 2.1609
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 2.2747
# Eval loss: 2.1387
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 2.1869
# Eval loss: 2.2413
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 2.2218
# Eval loss: 2.1289
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 2.4845
# Eval loss: 2.1209
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 2.2013
# Eval loss: 2.2049
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 2.3274
# Eval loss: 2.6436
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 2.4389
# Eval loss: 2.3612
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 2.3156
# Eval loss: 2.2543
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 2.2
# Eval loss: 2.1886
# --------------------------------------------------------------------------
# Training ended!
# Saved final model in custom_beta_VAE/VAE_training_2023-05-17_02-23-43/final_model

# %%
gen_data = sample_model(trained_model)
gen_data = gen_data.cpu()
show_generated_data(gen_data, eval_dataset[select], ppm)
# Out:
# (2048,)
# (2048,)
# (2048,)
# MSE: 0.0012756583908119087

# %%
# %%capture
config, model_config = basic_VAE_config()

wandb_callback = get_callback(config, model_config)

encoder = MRS_encoder(model_config)
decoder = MRS_decoder(model_config)
model = get_model(model_config, encoder, decoder)

pipeline = get_pipeline(model, config)

trained_model = train('basic_MRS_VAE', pipeline, train_dataset, eval_dataset, wandb_callback)
# Out:
# Preprocessing train data...
# Checking train dataset...
# Preprocessing eval data...
#
# Checking eval dataset...
# Using Base Trainer
#
# Model passed sanity check !
# Ready for training.
#
# Created basic_MRS_VAE/VAE_training_2023-05-17_02-27-08.
# Training config, checkpoints and final model will be saved here.
#
# Training params:
#  - max_epochs: 250
#  - per_device_train_batch_size: 64
#  - per_device_eval_batch_size: 64
#  - checkpoint saving every: None
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.91, 0.99)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.0002
#     maximize: False
#     weight_decay: 0.05
# )
# Scheduler: None
#
# Successfully launched training !
#
# --------------------------------------------------------------------------
# Train loss: 433.5704
# Eval loss: 34.5329
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 306.0092
# Eval loss: 35.1564
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 209.3728
# Eval loss: 33.3492
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 178.8356
# Eval loss: 33.8915
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 107.3468
# Eval loss: 37.482
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 114.3622
# Eval loss: 39.7045
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 68.15
# Eval loss: 40.761
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 53.7974
# Eval loss: 42.3034
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 52.7098
# Eval loss: 41.808
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 38.7498
# Eval loss: 46.1975
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 38.2669
# Eval loss: 48.0115
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 32.6269
# Eval loss: 51.4352
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 78.1335
# Eval loss: 52.669
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 33.769
# Eval loss: 56.315
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 88.3008
# Eval loss: 60.4256
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 35.5354
# Eval loss: 65.3454
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 41.9533
# Eval loss: 61.1529
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 38.6088
# Eval loss: 56.0412
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 30.935
# Eval loss: 53.7406
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 35.9954
# Eval loss: 54.9939
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 28.1241
# Eval loss: 49.2616
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 35.5932
# Eval loss: 41.6759
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 28.7962
# Eval loss: 40.7972
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 28.9589
# Eval loss: 36.4908
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 25.6006
# Eval loss: 33.7615
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 24.7756
# Eval loss: 33.231
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 31.3093
# Eval loss: 32.3871
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 24.0432
# Eval loss: 29.2982
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 33.1375
# Eval loss: 28.9376
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 26.5127
# Eval loss: 27.2504
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 27.4719
# Eval loss: 25.6595
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 26.2975
# Eval loss: 27.0329
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 30.1234
# Eval loss: 24.8768
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 25.5667
# Eval loss: 34.6514
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 26.1761
# Eval loss: 24.9918
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 23.8432
# Eval loss: 29.5034
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 24.4431
# Eval loss: 25.0537
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 34.0109
# Eval loss: 24.3623
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 24.0873
# Eval loss: 40.3774
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 23.5245
# Eval loss: 23.6235
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 24.549
# Eval loss: 23.0632
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 23.8486
# Eval loss: 22.9422
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 24.1497
# Eval loss: 23.1625
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 22.8827
# Eval loss: 22.5255
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 22.9088
# Eval loss: 22.6526
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 22.3233
# Eval loss: 29.3727
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 22.1896
# Eval loss: 24.5229
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 23.3966
# Eval loss: 21.6325
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 24.3001
# Eval loss: 39.7259
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 23.717
# Eval loss: 21.7673
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 23.2815
# Eval loss: 21.6429
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 22.6773
# Eval loss: 34.5004
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 21.9364
# Eval loss: 42.8257
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 22.3774
# Eval loss: 23.3842
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 22.2536
# Eval loss: 21.8046
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 24.2096
# Eval loss: 21.6457
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 22.0847
# Eval loss: 21.6277
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 22.0832
# Eval loss: 43.2428
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 22.0138
# Eval loss: 36.9538
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 23.0082
# Eval loss: 21.7396
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 22.0723
# Eval loss: 21.9939
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 22.2311
# Eval loss: 21.6025
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 22.4795
# Eval loss: 21.3826
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 21.5638
# Eval loss: 25.4014
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 21.6227
# Eval loss: 25.9196
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 26.9253
# Eval loss: 21.2898
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 22.2181
# Eval loss: 24.6956
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 23.1823
# Eval loss: 21.292
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 22.6018
# Eval loss: 21.7291
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 22.264
# Eval loss: 31.4368
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 22.5474
# Eval loss: 22.3149
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 21.7333
# Eval loss: 21.7772
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 21.8727
# Eval loss: 21.7871
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 22.142
# Eval loss: 21.6063
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 25.6812
# Eval loss: 21.3399
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 27.7916
# Eval loss: 21.3465
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 22.3556
# Eval loss: 21.658
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 23.522
# Eval loss: 25.3753
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 22.7307
# Eval loss: 22.2567
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 22.3764
# Eval loss: 22.2102
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 23.381
# Eval loss: 21.8106
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 26.1252
# Eval loss: 21.6137
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 21.8615
# Eval loss: 21.9013
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 22.3568
# Eval loss: 21.7801
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 23.2656
# Eval loss: 22.6205
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 21.6979
# Eval loss: 21.6988
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 22.8377
# Eval loss: 22.6645
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 21.4623
# Eval loss: 24.0842
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 23.8848
# Eval loss: 21.3092
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 24.1334
# Eval loss: 21.9912
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 22.8751
# Eval loss: 22.4115
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 21.6053
# Eval loss: 21.5386
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 21.9665
# Eval loss: 21.5205
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 21.7286
# Eval loss: 22.093
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 22.4735
# Eval loss: 22.5381
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 21.8434
# Eval loss: 21.0222
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 21.7815
# Eval loss: 22.2699
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 21.2653
# Eval loss: 20.9216
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 21.6834
# Eval loss: 21.6639
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 21.7054
# Eval loss: 20.8649
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 21.6403
# Eval loss: 21.2804
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 21.4283
# Eval loss: 21.1256
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 21.2401
# Eval loss: 21.077
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 21.7108
# Eval loss: 20.939
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 21.4237
# Eval loss: 20.9759
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 21.0322
# Eval loss: 21.3347
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 21.3716
# Eval loss: 20.6205
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 20.7291
# Eval loss: 20.6296
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 21.1714
# Eval loss: 20.5953
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 20.8661
# Eval loss: 21.6924
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 21.0787
# Eval loss: 20.78
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 21.3423
# Eval loss: 21.5905
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 21.204
# Eval loss: 20.523
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 20.832
# Eval loss: 20.2354
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 20.8956
# Eval loss: 20.2169
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 20.5082
# Eval loss: 20.821
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 20.6384
# Eval loss: 19.9526
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 20.4131
# Eval loss: 19.9345
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 20.3219
# Eval loss: 19.7348
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 20.4972
# Eval loss: 19.9822
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 20.8499
# Eval loss: 19.459
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 20.3314
# Eval loss: 19.6204
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 20.0127
# Eval loss: 19.8331
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 20.3569
# Eval loss: 19.6627
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 20.4618
# Eval loss: 19.4199
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 19.7781
# Eval loss: 19.0487
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 19.4996
# Eval loss: 18.817
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 20.4606
# Eval loss: 19.1998
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 19.7683
# Eval loss: 18.8651
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 19.1074
# Eval loss: 18.859
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 19.293
# Eval loss: 18.5729
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 19.0563
# Eval loss: 19.0048
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 19.323
# Eval loss: 18.2332
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 19.1809
# Eval loss: 18.4612
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 18.765
# Eval loss: 20.6509
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 18.3661
# Eval loss: 18.3487
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 18.7785
# Eval loss: 18.4233
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 18.473
# Eval loss: 17.7545
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 19.5584
# Eval loss: 17.8402
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 18.896
# Eval loss: 17.635
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 18.1772
# Eval loss: 18.2839
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 18.1747
# Eval loss: 18.1007
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 18.1397
# Eval loss: 17.6506
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 18.028
# Eval loss: 17.9237
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 17.7044
# Eval loss: 19.5878
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 17.5983
# Eval loss: 21.3138
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 18.0679
# Eval loss: 18.2344
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 17.7498
# Eval loss: 16.172
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 17.4544
# Eval loss: 17.2407
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 16.8393
# Eval loss: 16.4153
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 16.8682
# Eval loss: 16.8202
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 16.7735
# Eval loss: 16.7043
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 16.723
# Eval loss: 16.4692
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 16.7305
# Eval loss: 16.1421
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 16.1877
# Eval loss: 15.592
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 16.3018
# Eval loss: 15.2699
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 15.7418
# Eval loss: 16.8105
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 15.7735
# Eval loss: 15.4037
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 15.5646
# Eval loss: 15.3613
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 15.9709
# Eval loss: 15.2741
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 15.8083
# Eval loss: 15.3465
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 15.3958
# Eval loss: 14.7019
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 15.3984
# Eval loss: 14.9202
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 14.9571
# Eval loss: 15.4177
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 15.9427
# Eval loss: 20.4003
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 14.7967
# Eval loss: 14.6201
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 14.6811
# Eval loss: 15.0746
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 14.4677
# Eval loss: 14.3776
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 14.2503
# Eval loss: 16.5323
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 14.3597
# Eval loss: 13.6057
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 14.4958
# Eval loss: 14.0234
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 13.9715
# Eval loss: 13.1743
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 13.9403
# Eval loss: 13.6344
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 14.1778
# Eval loss: 12.8823
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 13.425
# Eval loss: 12.7318
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 13.5912
# Eval loss: 14.4222
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 14.0054
# Eval loss: 13.4431
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 12.887
# Eval loss: 15.5239
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 13.1844
# Eval loss: 13.464
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 12.37
# Eval loss: 13.7669
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 16.2014
# Eval loss: 13.5372
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 12.6802
# Eval loss: 12.7578
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 13.2889
# Eval loss: 12.6368
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 13.8672
# Eval loss: 11.9791
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 12.2846
# Eval loss: 12.4314
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 12.9485
# Eval loss: 12.6096
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 11.8276
# Eval loss: 12.7024
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 10.9771
# Eval loss: 12.6554
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 13.843
# Eval loss: 12.4971
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 10.8819
# Eval loss: 12.2302
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 11.3576
# Eval loss: 10.7998
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 10.6453
# Eval loss: 10.7374
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 10.9028
# Eval loss: 10.4282
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 10.6429
# Eval loss: 18.9912
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 10.5837
# Eval loss: 18.8433
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 12.7534
# Eval loss: 10.5927
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 10.0645
# Eval loss: 10.8599
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 10.6108
# Eval loss: 22.4482
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 10.5747
# Eval loss: 10.5247
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 10.5046
# Eval loss: 21.4876
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 9.5118
# Eval loss: 10.6147
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 9.443
# Eval loss: 10.5113
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 9.1878
# Eval loss: 9.148
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 9.1389
# Eval loss: 8.1249
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 9.566
# Eval loss: 8.4282
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 8.6851
# Eval loss: 11.3162
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 8.5011
# Eval loss: 8.352
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 8.3668
# Eval loss: 9.1298
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 8.0297
# Eval loss: 7.7363
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 7.7724
# Eval loss: 8.0005
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 7.8619
# Eval loss: 7.9272
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 7.8785
# Eval loss: 7.1245
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 9.2821
# Eval loss: 6.9632
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 7.354
# Eval loss: 8.6199
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 7.0352
# Eval loss: 7.9318
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 7.7808
# Eval loss: 9.4239
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 7.7446
# Eval loss: 8.2833
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 7.3257
# Eval loss: 7.8933
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 7.2841
# Eval loss: 15.8829
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 6.9514
# Eval loss: 7.4186
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 6.7473
# Eval loss: 10.6417
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 6.9143
# Eval loss: 6.2936
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 7.107
# Eval loss: 13.2528
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 6.8674
# Eval loss: 5.9972
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 6.2927
# Eval loss: 6.5101
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 5.8714
# Eval loss: 6.5329
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 6.1859
# Eval loss: 6.3825
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 6.0949
# Eval loss: 5.9603
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 5.4636
# Eval loss: 8.3672
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 5.6747
# Eval loss: 6.2642
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 5.864
# Eval loss: 5.8302
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 5.7601
# Eval loss: 5.801
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 5.8628
# Eval loss: 5.632
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 6.1704
# Eval loss: 5.1986
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 5.3775
# Eval loss: 9.0025
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 4.9405
# Eval loss: 4.9378
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 5.7825
# Eval loss: 5.4271
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 5.2646
# Eval loss: 8.0518
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 4.9123
# Eval loss: 4.8709
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 4.7293
# Eval loss: 6.1533
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 4.6562
# Eval loss: 4.6534
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 4.8469
# Eval loss: 4.4643
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 4.5778
# Eval loss: 4.5479
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 4.4139
# Eval loss: 4.3587
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 4.2538
# Eval loss: 4.6544
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 4.4947
# Eval loss: 4.4707
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 4.2969
# Eval loss: 4.1211
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 4.1484
# Eval loss: 4.0956
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 4.0161
# Eval loss: 4.0448
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Train loss: 3.9194
# Eval loss: 3.9219
# --------------------------------------------------------------------------
# Training ended!
# Saved final model in basic_MRS_VAE/VAE_training_2023-05-17_02-27-08/final_model

# %%
gen_data = sample_model(trained_model)
gen_data = gen_data.cpu()
show_generated_data(gen_data, eval_dataset[select], ppm)
# Out:
# (2048,)
# (2048,)
# (2048,)
# MSE: 0.0021452478791456247
